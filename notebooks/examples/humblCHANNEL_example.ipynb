# %%
# %load_ext autoreload
# %autoreload

from openbb import obb

from humbldata.core.utils.env import Env
from humbldata.toolbox.toolbox_controller import Toolbox

# obb.account.login(pat=Env().OBB_PAT, remember_me=True)

toolbox = Toolbox(
    symbols="SPY",
    interval="1d",
    start_date="2024-01-01",
    end_date="2025-04-16",
    membership="admin"
)
toolbox
# Out:
# Toolbox(symbols=['SPY'], interval=1d, start_date=2024-01-01, end_date=2025-04-16, provider=yfinance, membership=admin)

# %%
# import nest_asyncio
# nest_asyncio.apply()

result = toolbox.technical.humbl_channel(
    historical=False,
    window="1mo",
    _boundary_group_down=False,
    chart=True,
    yesterday_close=False,
    rv_adjustment=True,
    rs_method="RS_max",
    momentum="shift",
)
result
# Out:
# INFO: HumblChannelFetcher || START: fetch_data (sync)
# DEBUG: HumblChannelFetcher || Running .transform_query()
# DEBUG: HumblChannelFetcher || Running .extract_data()
# DEBUG: HumblChannelFetcher || Running .transform_data()
# DEBUG: humbl_momentum.model || Calculating momentum using method: shift, window: 31
# DEBUG: humbl_momentum.model || Using simple shift calculation
# INFO: HumblChannelFetcher || END: fetch_data (sync) - Total time: 0.2216s
# HumblObject
#
# id: 0680085e-7d3d-7135-8000-12394507e51d
# results: b'DSL_VERSION\x00\x00\x00\x00\x81\xadDataFrameScan\x82\xa2df\xc5\x05X\xff\...
# equity_data: b'DSL_VERSION\x00\x00\x00\x00\x81\xa6Filter\x82\xa5input\x81\xa4Join\x...
# provider: yfinance
# warnings: []
# chart: [{'content': '{"data":[{"line":{"color":"blue","width":2},"mode":"lines","na...
# extra: {}
# context_params: {'symbols': ['SPY'], 'interval': '1d', 'start_date': datetime.date(...
# command_params: {'window': '1mo', 'rv_adjustment': True, 'rv_method': 'std', 'rs_me...

# %%
result.to_polars(equity_data=False)
# Out:
# shape: (293, 6)
# ┌────────────┬────────┬──────────────┬──────────────┬───────────┬─────────────────┐
# │ date       ┆ symbol ┆ bottom_price ┆ recent_price ┆ top_price ┆ momentum_signal │
# │ ---        ┆ ---    ┆ ---          ┆ ---          ┆ ---       ┆ ---             │
# │ date       ┆ str    ┆ f64          ┆ f64          ┆ f64       ┆ i8              │
# ╞════════════╪════════╪══════════════╪══════════════╪═══════════╪═════════════════╡
# │ 2024-02-15 ┆ SPY    ┆ 492.9346     ┆ 502.01001    ┆ 506.9295  ┆ 1               │
# │ 2024-02-16 ┆ SPY    ┆ 494.2965     ┆ 499.51001    ┆ 509.1391  ┆ 1               │
# │ 2024-02-20 ┆ SPY    ┆ 489.6689     ┆ 496.76001    ┆ 508.7384  ┆ 1               │
# │ 2024-02-21 ┆ SPY    ┆ 490.5971     ┆ 497.209991   ┆ 508.7976  ┆ 1               │
# │ 2024-02-22 ┆ SPY    ┆ 494.7605     ┆ 507.5        ┆ 511.0984  ┆ 1               │
# │ …          ┆ …      ┆ …            ┆ …            ┆ …         ┆ …               │
# │ 2025-04-10 ┆ SPY    ┆ 507.6503     ┆ 524.580017   ┆ 540.7069  ┆ 0               │
# │ 2025-04-11 ┆ SPY    ┆ 513.635      ┆ 533.940002   ┆ 547.4984  ┆ 0               │
# │ 2025-04-14 ┆ SPY    ┆ 514.4157     ┆ 539.119995   ┆ 549.0911  ┆ 0               │
