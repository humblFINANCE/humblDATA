# %%
# %load_ext autoreload
# %autoreload

from openbb import obb

from humbldata.core.utils.env import Env
from humbldata.toolbox.toolbox_controller import Toolbox

# obb.account.login(pat=Env().OBB_PAT, remember_me=True)

toolbox = Toolbox(
    symbols="MP",
    interval="1d",
    start_date="2000-01-01",
    end_date="2025-04-22",
    membership="admin"
)
toolbox
# Out:
# Toolbox(symbols=['MP'], interval=1d, start_date=2000-01-01, end_date=2025-04-22, provider=yfinance, membership=admin)

# %%
# import nest_asyncio
# nest_asyncio.apply()

result = toolbox.technical.humbl_channel(
    historical=False,
    window="1mo",
    _boundary_group_down=False,
    chart=True,
    yesterday_close=False,
    rv_adjustment=True,
    rs_method="RS_max",
    momentum="shift",

)
result
# Out:
# INFO: HumblChannelFetcher || START: fetch_data (sync)
# DEBUG: HumblChannelFetcher || Running .transform_query()
# DEBUG: HumblChannelFetcher || Running .extract_data()
# DEBUG: HumblChannelFetcher || Running .transform_data()
# DEBUG: humbl_momentum.model || Calculating momentum using method: log, window: 30
# DEBUG: humbl_momentum.model || Using logarithmic ROC calculation
# INFO: HumblChannelFetcher || END: fetch_data (sync) - Total time: 2.3885s
# HumblObject
#
# id: 0681d838-fb8e-7cd8-8000-c568f7c72bff
# results: b'DSL_VERSION\x01\x00\x00\x00\x81\xadDataFrameScan\x82\xa2df\xc5\x05X\xff\...
# equity_data: b'DSL_VERSION\x01\x00\x00\x00\x81\xa2IR\x82\xa3dsl\x81\xa6HStack\x83\x...
# provider: yfinance
# warnings: []
# chart: [{'content': '{"data":[{"line":{"color":"blue","width":2},"mode":"lines","na...
# extra: {}
# context_params: {'symbols': ['MP'], 'interval': '1d', 'start_date': datetime.date(2...
# command_params: {'window': '1mo', 'rv_adjustment': True, 'rv_method': 'std', 'rs_me...

# %%
result.to_polars(equity_data=False)
# Out:
# shape: (1, 6)
# ┌────────────┬────────┬──────────────┬──────────────┬───────────┬─────────────────┐
# │ date       ┆ symbol ┆ bottom_price ┆ recent_price ┆ top_price ┆ momentum_signal │
# │ ---        ┆ ---    ┆ ---          ┆ ---          ┆ ---       ┆ ---             │
# │ date       ┆ str    ┆ f64          ┆ f64          ┆ f64       ┆ i8              │
# ╞════════════╪════════╪══════════════╪══════════════╪═══════════╪═════════════════╡
# │ 2025-04-16 ┆ SPY    ┆ 498.5708     ┆ 525.659973   ┆ 541.2105  ┆ 0               │
# └────────────┴────────┴──────────────┴──────────────┴───────────┴─────────────────┘

# %%
print(result.to_json(chart=True))
# Out:
# ['{"data":[{"line":{"color":"blue","width":2},"mode":"lines","name":"Price (Positive Momentum)","x":["2000-03-09","2000-03-10",null,"2000-03-13","2000-03-14",null,"2000-03-16","2000-03-17","2000-03-20","2000-03-21","2000-03-22","2000-03-23","2000-03-24","2000-03-27","2000-03-28","2000-03-29","2000-03-30","2000-03-31","2000-04-03","2000-04-04","2000-04-05","2000-04-06","2000-04-07","2000-04-10","2000-04-11","2000-04-12","2000-04-13","2000-04-14",null,"2000-04-17","2000-04-18","2000-04-19","2000-04-20","2000-04-24","2000-04-25","2000-04-26","2000-04-27","2000-04-28",null,"2000-05-01","2000-05-02",null,"2000-05-30","2000-05-31","2000-06-01","2000-06-02","2000-06-05","2000-06-06","2000-06-07",null,"2000-06-08","2000-06-09","2000-06-12",null,"2000-06-13","2000-06-14","2000-06-15","2000-06-16","2000-06-19","2000-06-20","2000-06-21","2000-06-22","2000-06-23","2000-06-26","2000-06-27",null,"2000-06-30","2