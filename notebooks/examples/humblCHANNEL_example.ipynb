# %%
# %load_ext autoreload
# %autoreload

from openbb import obb

from humbldata.core.utils.env import Env
from humbldata.toolbox.toolbox_controller import Toolbox

# obb.account.login(pat=Env().OBB_PAT, remember_me=True)

toolbox = Toolbox(
    symbols="MP",
    interval="1d",
    start_date="2000-01-01",
    end_date="2025-04-22",
    membership="admin"
)
toolbox
# Out:
# Toolbox(symbols=['MP'], interval=1d, start_date=2000-01-01, end_date=2025-04-22, provider=yfinance, membership=admin)

# %%
# import nest_asyncio
# nest_asyncio.apply()

result = toolbox.technical.humbl_channel(
    historical=False,
    window="1mo",
    _boundary_group_down=False,
    chart=True,
    yesterday_close=False,
    rv_adjustment=True,
    rs_method="RS_max",
    momentum="shift",

)
result
# Out:
# INFO: HumblChannelFetcher || START: fetch_data (sync)
# DEBUG: HumblChannelFetcher || Running .transform_query()
# DEBUG: HumblChannelFetcher || Running .extract_data()
# DEBUG: HumblChannelFetcher || Running .transform_data()
# DEBUG: humbl_momentum.model || Calculating momentum using method: shift, window: 31
# DEBUG: humbl_momentum.model || Using simple shift calculation
# INFO: HumblChannelFetcher || END: fetch_data (sync) - Total time: 0.2959s
# HumblObject
#
# id: 06809846-4f3b-7ea9-8000-91aae9bc6764
# results: b'DSL_VERSION\x00\x00\x00\x00\x81\xadDataFrameScan\x82\xa2df\xc5\x05X\xff\...
# equity_data: b'DSL_VERSION\x00\x00\x00\x00\x81\xa6Filter\x82\xa5input\x81\xa4Join\x...
# provider: yfinance
# warnings: []
# chart: [{'content': '{"data":[{"line":{"color":"blue","width":2},"mode":"lines","na...
# extra: {}
# context_params: {'symbols': ['MP'], 'interval': '1d', 'start_date': datetime.date(2...
# command_params: {'window': '1mo', 'rv_adjustment': True, 'rv_method': 'std', 'rs_me...

# %%
result.to_polars(equity_data=False)
# Out:
# shape: (1, 6)
# ┌────────────┬────────┬──────────────┬──────────────┬───────────┬─────────────────┐
# │ date       ┆ symbol ┆ bottom_price ┆ recent_price ┆ top_price ┆ momentum_signal │
# │ ---        ┆ ---    ┆ ---          ┆ ---          ┆ ---       ┆ ---             │
# │ date       ┆ str    ┆ f64          ┆ f64          ┆ f64       ┆ i8              │
# ╞════════════╪════════╪══════════════╪══════════════╪═══════════╪═════════════════╡
# │ 2025-04-22 ┆ MP     ┆ 20.9391      ┆ 22.85        ┆ 26.2985   ┆ 0               │
# └────────────┴────────┴──────────────┴──────────────┴───────────┴─────────────────┘

# %%
print(result.to_json(chart=True))
# Out:
# ['{"data":[{"line":{"color":"blue","width":2},"mode":"lines","name":"Price (Positive Momentum)","x":["2020-08-05","2020-08-05","2020-08-06","2020-08-07","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-31","2020-09-01","2020-09-02","2020-09-03",null,"2020-09-04","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-28","2020-09-29","2020-09-30","2020-10-01","2020-10-02","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-12","2020-10-13","2020-10-14",null,"2020-10-15","2020-10-16",null,"2020-11-12","2020-11-13",null,"2020-11-17","2020-11-18","2020-11-19","2020-11-20","2020-11-23","2020-11-24","2020-11-25","2020-11-27","2020-11-30","2020-12-01","2020-12-02","2020-12-03","2020-12-04","2020-12-07","2020-12-08","2020-12-09","2020-12-10","2020-12-11","2020-12-14","2020-12-15","2020-12-16","2020-12-17","2020-12-18","2020-12-21","2020-12-22","2020-12-23","2020-12-24","2020-12-28","2020-12-29","2020-12-30","2020-12-31","2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05",null,"2021-02-10","2021-02-11","2021-02-12","2021-02-16","2021-02-17","2021-02-18","2021-02-19","2021-02-22","2021-02-23","2021-02-24","2021-02-25","2021-02-26","2021-03-01","2021-03-02","2021-03-03","2021-03-04","2021-03-05","2021-03-08","2021-03-09","2021-03-10","2021-03-11","2021-03-12","2021-03-15","2021-03-16","2021-03-17","2021-03-18","2021-03-19","2021-03-22","2021-03-23","2021-03-24","2021-03-25","2021-03-26",null,"2021-06-02","2021-06-03","2021-06-04","2021-06-07","2021-06-08","2021-06-09","2021-06-10","2021-06-11","2021-06-14","2021-06-15","2021-06-16","2021-06-17","2021-06-18",null,"2021-06-21","2021-06-22","2021-06-23","2021-06-24","2021-06-25","2021-06-28","2021-06-29","2021-06-30","2021-07-01","2021-07-02","2021-07-06","2021-07-07","2021-07-08","2021-07-09","2021-07-12","2021-07-13","2021-07-14","2021-07-15","2021-07-16","2021-07-19","2021-07-20","2021-07-21","2021-07-22",null,"2021-07-23","2021-07-26","2021-07-27","2021-07-28","2021-07-29","2021-07-30","2021-08-02","2021-08-03","2021-08-04","2021-08-05","2021-08-06","2021-08-09","2021-08-10","2021-08-11","2021-08-12","2021-08-13",null,"2021-08-30","2021-08-31","2021-09-01",null,"2021-09-03","2021-09-07",null,"2021-10-15","2021-10-18",null,"2021-10-19","2021-10-20","2021-10-21","2021-10-22","2021-10-25","2021-10-26",null,"2021-11-01","2021-11-02","2021-11-03","2021-11-04","2021-11-05","2021-11-08","2021-11-09","2021-11-10","2021-11-11","2021-11-12","2021-11-15","2021-11-16","2021-11-17","2021-11-18","2021-11-19","2021-11-22","2021-11-23","2021-11-24","2021-11-26","2021-11-29","2021-11-30","2021-12-01","2021-12-02","2021-12-03","2021-12-06","2021-12-07","2021-12-08","2021-12-09","2021-12-10","2021-12-13","2021-12-14","2021-12-15","2021-12-16","2021-12-17","2021-12-20","2021-12-21","2021-12-22","2021-12-23","2021-12-27","2021-12-28","2021-12-29",null,"2021-12-30","2021-12-31","2022-01-03","2022-01-04","2022-01-05","2022-01-06","2022-01-07","2022-01-10","2022-01-11","2022-01-12","2022-01-13","2022-01-14","2022-01-18","2022-01-19","2022-01-20","2022-01-21",null,"2022-03-08","2022-03-09","2022-03-10","2022-03-11","2022-03-14","2022-03-15","2022-03-16","2022-03-17","2022-03-18","2022-03-21","2022-03-22","2022-03-23","2022-03-24","2022-03-25","2022-03-28","2022-03-29","2022-03-30","2022-03-31","2022-04-01","2022-04-04","2022-04-05","2022-04-06","2022-04-07","2022-04-08","2022-04-11","2022-04-12","2022-04-13","2022-04-14","2022-04-18","2022-04-19","2 ...

# %%
result.warnings
# Out:
# [Warning_(category='HumblDataWarning', message="`recent_price` is representing yesterday's close price.")]

# %%
import time

start = time.time()
result.show()
end = time.time()
print(f"Time elapsed: {end - start:.2f} seconds")
# Out:
# Time elapsed: 0.02 seconds
